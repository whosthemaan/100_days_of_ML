# %%
import pandas as pd
import requests

# %%
result = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8315254a43010c2b6c649fabd65685c9')

# %%
pd.DataFrame(result.json()['results'])
# Out:
#     adult                     backdrop_path            genre_ids      id  \
# 0   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg             [18, 80]     238
# 1   False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg             [18, 80]     278
# 2   False  /ejnlCzBd5pOGAYCpxC93NXSrdrz.jpg             [35, 14]  772071
# 3   False  /oo4PVK6AyLZN49BokxDFGyclN86.jpg             [18, 80]     240
# 4   False  /vI3aUGTuRRdM7J78KIdW98LdxE5.jpg      [35, 18, 10749]   19404
# 5   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg      [18, 36, 10752]     424
# 6   False  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg      [16, 10751, 14]     129
# 7   False  /tj6iPnz18hGfr0LKqWmG6Cp3niO.jpg                 [18]     389
# 8   False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg      [10749, 16, 18]  372058
# 9   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg         [35, 53, 18]  496243
# 10  False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg     [18, 28, 80, 53]     155
# 11  False  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg         [14, 18, 80]     497
# ...

# %%
df = pd.DataFrame(result.json()['results']).head(2)[['id', 'title']]

# %%
df.to_csv('exporting_movie.csv')
